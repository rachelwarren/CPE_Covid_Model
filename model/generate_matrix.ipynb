# %%
import pandas as pd
import numpy as np

# %%
#expanded matrix

ls = []
for race in ['White', 'Black']:
    for labour_type in ['Forced_Labour', 'Non_Essential_Labour', 'Police']:
        for loc in ['At_Work', 'At_Home']:
            simple_name = f'{race}_{labour_type}' if labour_type != 'Non_Essential_Labour' else race
            
            ls.append(
                {'Race' : race,
                 'Labour_Type' : labour_type,
                 'Location': loc,
                 'i': f'{race}_{labour_type}_{loc}',
                 'Sub_Group_Name': f'{race}_{labour_type}',
                'Group_Name': simple_name})
    
    ls.append({'Race': race,'Labour_Type': 'Non_Working','Location': 'At_Home',
               'Sub_Group_Name': f'{race}_Non_Working', 'i': f'{race}_Non_Working', 'Group_Name': race})
    ls.append({'Race': race, 'Labour_Type': 'Prison',
               'Sub_Group_Name': f'{race}_Prison', 'i': f'{race}_Prison', 'Group_Name': f'{race}_Prison'})

group_df = pd.DataFrame(ls)
group_df = group_df.set_index('i')
group_df
# Out:
#                                      Race           Labour_Type Location  \
# i
# White_Forced_Labour_At_Work         White         Forced_Labour  At_Work
# White_Forced_Labour_At_Home         White         Forced_Labour  At_Home
# White_Non_Essential_Labour_At_Work  White  Non_Essential_Labour  At_Work
# White_Non_Essential_Labour_At_Home  White  Non_Essential_Labour  At_Home
# White_Police_At_Work                White                Police  At_Work
# White_Police_At_Home                White                Police  At_Home
# White_Non_Working                   White           Non_Working  At_Home
# White_Prison                        White                Prison      NaN
# Black_Forced_Labour_At_Work         Black         Forced_Labour  At_Work
# Black_Forced_Labour_At_Home         Black         Forced_Labour  At_Home
# Black_Non_Essential_Labour_At_Work  Black  Non_Essential_Labour  At_Work
# Black_Non_Essential_Labour_At_Home  Black  Non_Essential_Labour  At_Home
# Black_Police_At_Work                Black                Police  At_Work
# Black_Police_At_Home                Black                Police  At_Home
# Black_Non_Working                   Black           Non_Working  At_Home
# Black_Prison                        Black                Prison      NaN
#
#                                                 Sub_Group_Name  \
# i
# White_Forced_Labour_At_Work                White_Forced_Labour
# White_Forced_Labour_At_Home                White_Forced_Labour
# White_Non_Essential_Labour_At_Work  White_Non_Essential_Labour
# White_Non_Essential_Labour_At_Home  White_Non_Essential_Labour
# White_Police_At_Work                              White_Police
# White_Police_At_Home                              White_Police
# White_Non_Working                            White_Non_Working
# White_Prison                                      White_Prison
# Black_Forced_Labour_At_Work                Black_Forced_Labour
# Black_Forced_Labour_At_Home                Black_Forced_Labour
# Black_Non_Essential_Labour_At_Work  Black_Non_Essential_Labour
# Black_Non_Essential_Labour_At_Home  Black_Non_Essential_Labour
# Black_Police_At_Work                              Black_Police
# Black_Police_At_Home                              Black_Police
# Black_Non_Working                            Black_Non_Working
# Black_Prison                                      Black_Prison
#
#                                              Group_Name
# i
# White_Forced_Labour_At_Work         White_Forced_Labour
# White_Forced_Labour_At_Home         White_Forced_Labour
# White_Non_Essential_Labour_At_Work                White
# White_Non_Essential_Labour_At_Home                White
# White_Police_At_Work                       White_Police
# White_Police_At_Home                       White_Police
# White_Non_Working                                 White
# White_Prison                               White_Prison
# Black_Forced_Labour_At_Work         Black_Forced_Labour
# Black_Forced_Labour_At_Home         Black_Forced_Labour
# Black_Non_Essential_Labour_At_Work                Black
# Black_Non_Essential_Labour_At_Home                Black
# Black_Police_At_Work                       Black_Police
# Black_Police_At_Home                       Black_Police
# Black_Non_Working                                 Black
# Black_Prison                               Black_Prison

# %%
# Share of Population 
group_sizes = {} #dictionary with size of the final population groups that we use keyed on sub group name
prop_of_race = {} #dictionary with proportion of that racial group in this group
WHITE_OF_ALL = .6040 #Group Size B35
BLACK_OF_ALL = 0.1340

ALL_AMERICANS = 328239523.00
WHITE_INCARCERATED_TOTAL = 804712.10 #Calculations B31
BLACK_INCARCERATED_TOTAL = 717931.20

white_total = WHITE_OF_ALL * ALL_AMERICANS
black_total = BLACK_OF_ALL * ALL_AMERICANS 


#?????
WHITE_OF_POLICE = 0.597  #proportion of police who are white
BLACK_OF_POLICE = 0.215 #proportion of police who are black

POLICE_OF_WHITE = 0.00167846 #B43 #proporiton of white who are police 
POLICE_OF_BLACK = 0.00272 #This seems real wierd ... 

prop_of_race['White_Police'] = POLICE_OF_WHITE
prop_of_race['Black_Police'] = POLICE_OF_BLACK

group_sizes['White_Police'] = POLICE_OF_WHITE * WHITE_OF_ALL
group_sizes['Black_Police'] = POLICE_OF_BLACK * BLACK_OF_ALL

#INCARCERATION 
#These are pull from the calculations spread sheet I don't know if they are write and I have not used the full calculations

INCARCE_OF_ALL = 0.0063 #Group Size Calculations B32
WHITE_OF_INCARCE = 0.5284967924 #Calculations J31 #proportion of prisoners who are white
BLACK_OF_INCARCE = 0.4715032076 #Calculations J32 

group_sizes['White_Prison'] = INCARCE_OF_ALL * WHITE_OF_INCARCE #Proportion of all people who white AND incarcerated Calculations D32
group_sizes['Black_Prison'] = INCARCE_OF_ALL * BLACK_OF_INCARCE  #Proportion of all black people who are incarcerated Calculations D33

prop_of_race['White_Prison'] = WHITE_INCARCERATED_TOTAL/white_total
prop_of_race['Black_Prison'] = BLACK_INCARCERATED_TOTAL/black_total

#Labour Groups 
FORCED_LABOUR_OF_WHITE = 0.1125  #proprotion of all white residents 
FORCED_LABOUR_OF_BLACK = 0.1362 #Proportion of all black residents

NON_ESSENTIAL_LABOUR_OF_WHITE = 0.3749 # B23
NON_ESSENTIAL_LABOUR_OF_BLACK = 0.30438 #B22 prop of black residents doing non essential labour

prop_of_race['White_Forced_Labour'] = FORCED_LABOUR_OF_WHITE
prop_of_race['Black_Forced_Labour'] = FORCED_LABOUR_OF_BLACK

prop_of_race['White_Non_Essential_Labour'] = NON_ESSENTIAL_LABOUR_OF_WHITE
prop_of_race['Black_Non_Essential_Labour'] = NON_ESSENTIAL_LABOUR_OF_BLACK


prop_of_race['White_Non_Working'] = 1 - prop_of_race['White_Prison'] - prop_of_race['White_Non_Essential_Labour'] - prop_of_race['White_Forced_Labour']

prop_of_race['Black_Non_Working'] = 1 - prop_of_race['Black_Prison'] - prop_of_race['Black_Non_Essential_Labour'] - prop_of_race['Black_Forced_Labour']

# group_sizes['White'] = WHITE_NON_ESSENTIAL_LABOUR_PROP + white_non_working
# group_sizes['Black'] = BLACK_NON_ESSENTIAL_LABOUR_PROP + black_non_working

# group_sizes['White_Forced_Labour'] = WHITE_PROP * (WHITE_FORCED_LABOUR_PROP)
# group_sizes['Black_Forced_Labour'] = BLACK_PROP * (BLACK_FORCED_LABOUR_PROP)


group_df['Proportion_of_Racial_Group'] = group_df['Sub_Group_Name'].replace(prop_of_race)

def group_size_fn(g):
    if g in group_sizes.keys():
        return group_sizes[g]
    else:
        if 'Black' in g:
            return prop_of_race[g] * BLACK_OF_ALL
        elif 'White' in g:
            return prop_of_race[g] * WHITE_OF_ALL
        else:
            return np.nan
        
group_df['Group_Size'] = group_df['Sub_Group_Name'].apply(group_size_fn)


group_df[['Sub_Group_Name', 'Proportion_of_Racial_Group', 'Group_Size']].drop_duplicates()
# Out:
#                                                 Sub_Group_Name  \
# i
# White_Forced_Labour_At_Work                White_Forced_Labour
# White_Non_Essential_Labour_At_Work  White_Non_Essential_Labour
# White_Police_At_Work                              White_Police
# White_Non_Working                            White_Non_Working
# White_Prison                                      White_Prison
# Black_Forced_Labour_At_Work                Black_Forced_Labour
# Black_Non_Essential_Labour_At_Work  Black_Non_Essential_Labour
# Black_Police_At_Work                              Black_Police
# Black_Non_Working                            Black_Non_Working
# Black_Prison                                      Black_Prison
#
#                                     Proportion_of_Racial_Group  Group_Size
# i
# White_Forced_Labour_At_Work                           0.112500    0.067950
# White_Non_Essential_Labour_At_Work                    0.374900    0.226440
# White_Police_At_Work                                  0.001678    0.001014
# White_Non_Working                                     0.508541    0.307159
# White_Prison                                          0.004059    0.003330
# Black_Forced_Labour_At_Work                           0.136200    0.018251
# Black_Non_Essential_Labour_At_Work                    0.304380    0.040787
# Black_Police_At_Work                                  0.002720    0.000364
# Black_Non_Working                                     0.543097    0.072775
# Black_Prison                                          0.016323    0.002970

# %%
# Fill in Hours in Neighborhood
#Calculation comves from Expanded may 7 pre social distanced model row 19 
group_df['Home_Hours'] = np.where(
    (group_df['Labour_Type'] == 'Non_Working'), 112,
        np.where((group_df['Labour_Type'] != 'Non_Working') & 
                 (group_df['Location'] == 'At_Home'), 72, 0))

group_df['Working_Hours'] = np.where(group_df['Location'] == 'At_Work', 40, 0)
group_df[['Home_Hours', 'Working_Hours']]
# Out:
#                                     Home_Hours  Working_Hours
# i
# White_Forced_Labour_At_Work                  0             40
# White_Forced_Labour_At_Home                 72              0
# White_Non_Essential_Labour_At_Work           0             40
# White_Non_Essential_Labour_At_Home          72              0
# White_Police_At_Work                         0             40
# White_Police_At_Home                        72              0
# White_Non_Working                          112              0
# White_Prison                                 0              0
# Black_Forced_Labour_At_Work                  0             40
# Black_Forced_Labour_At_Home                 72              0
# Black_Non_Essential_Labour_At_Work           0             40
# Black_Non_Essential_Labour_At_Home          72              0
# Black_Police_At_Work                         0             40
# Black_Police_At_Home                        72              0
# Black_Non_Working                          112              0
# Black_Prison                                 0              0

# %%
group_df['Race_Home_Hours'] = group_df['Home_Hours'] * group_df['Proportion_of_Racial_Group']
group_df['Race_Work_Hours'] = group_df['Working_Hours'] * group_df['Proportion_of_Racial_Group']

# %%
group_df[['Home_Hours', 'Proportion_of_Racial_Group', 'Race_Work_Hours', 'Race_Home_Hours']]
# Out:
#                                     Home_Hours  Proportion_of_Racial_Group  \
# i
# White_Forced_Labour_At_Work                  0                    0.112500
# White_Forced_Labour_At_Home                 72                    0.112500
# White_Non_Essential_Labour_At_Work           0                    0.374900
# White_Non_Essential_Labour_At_Home          72                    0.374900
# White_Police_At_Work                         0                    0.001678
# White_Police_At_Home                        72                    0.001678
# White_Non_Working                          112                    0.508541
# White_Prison                                 0                    0.004059
# Black_Forced_Labour_At_Work                  0                    0.136200
# Black_Forced_Labour_At_Home                 72                    0.136200
# Black_Non_Essential_Labour_At_Work           0                    0.304380
# Black_Non_Essential_Labour_At_Home          72                    0.304380
# Black_Police_At_Work                         0                    0.002720
# Black_Police_At_Home                        72                    0.002720
# Black_Non_Working                          112                    0.543097
# Black_Prison                                 0                    0.016323
#
#                                     Race_Work_Hours  Race_Home_Hours
# i
# White_Forced_Labour_At_Work                4.500000         0.000000
# White_Forced_Labour_At_Home                0.000000         8.100000
# White_Non_Essential_Labour_At_Work        14.996000         0.000000
# White_Non_Essential_Labour_At_Home         0.000000        26.992800
# White_Police_At_Work                       0.067138         0.000000
# White_Police_At_Home                       0.000000         0.120849
# White_Non_Working                          0.000000        56.956599
# White_Prison                               0.000000         0.000000
# Black_Forced_Labour_At_Work                5.448000         0.000000
# Black_Forced_Labour_At_Home                0.000000         9.806400
# Black_Non_Essential_Labour_At_Work        12.175200         0.000000
# Black_Non_Essential_Labour_At_Home         0.000000        21.915360
# Black_Police_At_Work                       0.108800         0.000000
# Black_Police_At_Home                       0.000000         0.195840
# Black_Non_Working                          0.000000        60.826918
# Black_Prison                               0.000000         0.000000

# %%
white_residential_hours = group_df[(group_df['Location'] == 'At_Home') & (group_df['Race'] == 'White')]['Race_Home_Hours'].sum()
black_residential_hours = group_df[(group_df['Location'] == 'At_Home') & (group_df['Race'] == 'Black')]['Race_Home_Hours'].sum()
print(f"resident hours --- white: {white_residential_hours}, black: {black_residential_hours}")
# Out:
# resident hours --- white: 92.1702477472447, black: 92.744517984031

# %%
# Create a new data frame for the contact matrix. 
contact_matrix = group_df[[]]
for g in group_df.index.values:
    contact_matrix[g] = 0.0
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.

# %%
SOCIAL_DISTANCING_INFECTION_RATE = 2.7
NO_SOCIAL_DISTANCING_INFECTION_RATE = 2.7
TRANSMISSION_RATE = 0.01
DAYS_UNTIL_RECOVERY = 21


social_distancing_contact_rate = NO_SOCIAL_DISTANCING_INFECTION_RATE/(TRANSMISSION_RATE * DAYS_UNTIL_RECOVERY)
ocupation_infection_number =  social_distancing_contact_rate
no_social_distancing_contact_rate = social_distancing_contact_rate
print(social_distancing_contact_rate)
#number of people this group contacts when at work
#this will change in the post social distancing world. 
group_df['labour_type_contact_rate'] = group_df['Labour_Type'].apply(
    lambda x: ocupation_infection_number*(112/40) if x in ['Prison', 'Police', 'Forced_Labour'] else (social_distancing_contact_rate))

#at home contact rates are no social distancing for now, but should be with social distancing in the future.
group_df['Target_Contacts'] = (group_df['Home_Hours']/112) * no_social_distancing_contact_rate +  group_df['labour_type_contact_rate'] * group_df['Working_Hours']/112
group_df[['labour_type_contact_rate', 'Home_Hours', 'Target_Contacts']]
# Out:
# 12.857142857142858
#                                     labour_type_contact_rate  Home_Hours  \
# i
# White_Forced_Labour_At_Work                        36.000000           0
# White_Forced_Labour_At_Home                        36.000000          72
# White_Non_Essential_Labour_At_Work                 12.857143           0
# White_Non_Essential_Labour_At_Home                 12.857143          72
# White_Police_At_Work                               36.000000           0
# White_Police_At_Home                               36.000000          72
# White_Non_Working                                  12.857143         112
# White_Prison                                       36.000000           0
# Black_Forced_Labour_At_Work                        36.000000           0
# Black_Forced_Labour_At_Home                        36.000000          72
# Black_Non_Essential_Labour_At_Work                 12.857143           0
# Black_Non_Essential_Labour_At_Home                 12.857143          72
# Black_Police_At_Work                               36.000000           0
# Black_Police_At_Home                               36.000000          72
# Black_Non_Working                                  12.857143         112
# Black_Prison                                       36.000000           0
#
#                                     Target_Contacts
# i
# White_Forced_Labour_At_Work               12.857143
# White_Forced_Labour_At_Home                8.265306
# White_Non_Essential_Labour_At_Work         4.591837
# White_Non_Essential_Labour_At_Home         8.265306
# White_Police_At_Work                      12.857143
# White_Police_At_Home                       8.265306
# White_Non_Working                         12.857143
# White_Prison                               0.000000
# Black_Forced_Labour_At_Work               12.857143
# Black_Forced_Labour_At_Home                8.265306
# Black_Non_Essential_Labour_At_Work         4.591837
# Black_Non_Essential_Labour_At_Home         8.265306
# Black_Police_At_Work                      12.857143
# Black_Police_At_Home                       8.265306
# Black_Non_Working                         12.857143
# Black_Prison                               0.000000

# %%
# white at work contact all other workers 
non_zero_contact_groups = {}
def fill_working_groups(m):
    #for all workers, they conctact only other workers at work. Proportional to types of workers, to hit the total contacts.
    #no one contacts police at work 
    worker_df = group_df[(group_df['Location'] == 'At_Work') & group_df['Labour_Type'].isin(['Forced_Labour', 'Non_Essential_Labour'])]
  
    total_worker_size = worker_df['Group_Size'].sum()
    worker_proportion = (worker_df['Group_Size']/total_worker_size)
    for a in worker_df.index.values:
        target_contacts = worker_df.loc[a, 'Target_Contacts']
        for b in worker_df.index.values:
            # if b is white non essential labour at work, then worker proportion is non essential labour / all working groups
            m.loc[a, b] = target_contacts * worker_proportion[b]
    return m

contact_matrix = fill_working_groups(contact_matrix)

# %%
white_of_black_white_police = WHITE_OF_POLICE/(WHITE_OF_POLICE + BLACK_OF_POLICE)
black_of_black_white_police = BLACK_OF_POLICE/(WHITE_OF_POLICE + BLACK_OF_POLICE)

POLICE_STOP_WHITE = 0.6895951865 #D16
POLICE_STOP_BLACK = 0.2751037807
TOTAL_OFFICER_STOPS = 10

police_contacts_with_whites = TOTAL_OFFICER_STOPS * POLICE_STOP_WHITE
police_contacts_with_blacks = TOTAL_OFFICER_STOPS * POLICE_STOP_BLACK
# police contact in white neighborhoods
# police --> white
white_police_contacts_with_whites = police_contacts_with_whites * white_of_black_white_police
black_police_contacts_with_whites = police_contacts_with_whites * black_of_black_white_police
# white --> police
whites_contact_with_white_police = white_police_contacts_with_whites * group_df.loc['White_Police_At_Work', 'Group_Size']/ WHITE_OF_ALL
whites_contact_with_black_police = black_police_contacts_with_whites * group_df.loc['Black_Police_At_Work', 'Group_Size']/ WHITE_OF_ALL

# police contacts in black neighborhoods
# police --> black
white_police_contacts_with_blacks = police_contacts_with_blacks * white_of_black_white_police
black_police_contacts_with_blacks = police_contacts_with_blacks * black_of_black_white_police
# black --> police
# blacks/police * (blacks / all) / (black_police / all) = black_police_contacts * black police / all blacks 
blacks_contact_with_black_police = black_police_contacts_with_blacks * group_df.loc['Black_Police_At_Work', 'Group_Size'] / BLACK_OF_ALL
blacks_contact_with_white_police = white_police_contacts_with_blacks * group_df.loc['White_Police_At_Work', 'Group_Size'] / BLACK_OF_ALL

home = group_df[(group_df['Location'] == 'At_Home')]

white_neighborhood = home[home['Race'] == 'White']
white_neighborhood['hours_prop'] = white_neighborhood['Race_Home_Hours']/white_neighborhood['Race_Home_Hours'].sum()
white_non_police = white_neighborhood[white_neighborhood['Labour_Type'] != 'Police'].index.values
black_neighborhood = home[home['Race'] == 'Black']
black_neighborhood['hours_prop'] = black_neighborhood['Race_Home_Hours']/black_neighborhood['Race_Home_Hours'].sum()
black_non_police = black_neighborhood[black_neighborhood['Labour_Type'] != 'Police'].index.values

MAX_OCCUPATION_INFECTION_NUMBER = 17 
MIN_OCCUPATION_INFECTION_NUMBER = 10

def fill_in_police_job_contacts(m):
    #police contacts are spread evenly by "race_home_hours" for a given neighborhood
    for person in white_non_police:
        prop = white_neighborhood.loc[person, 'hours_prop']
        
        m.loc['White_Police_At_Work', person] = white_police_contacts_with_whites * prop
        m.loc['Black_Police_At_Work', person] = black_police_contacts_with_whites * prop
        
        # HELP!!! These numbers seem not to match up with what the google sheet has
        time = group_df.loc[person, 'Home_Hours']/112
        m.loc[person, 'White_Police_At_Work'] = whites_contact_with_white_police * time
        m.loc[person, 'Black_Police_At_Work'] = whites_contact_with_black_police * time
    
    for person in black_non_police:
        prop = black_neighborhood.loc[person, 'hours_prop']
        print(person)
        m.loc['White_Police_At_Work', person] = white_police_contacts_with_blacks * prop
        m.loc['Black_Police_At_Work', person] = black_police_contacts_with_blacks * prop
        
         # HELP!!! These numbers seem not to match up with what the google sheet has
        time = group_df.loc[person, 'Home_Hours']/112
        m.loc[person, 'White_Police_At_Work'] = blacks_contact_with_white_police * time
        m.loc[person, 'Black_Police_At_Work'] = blacks_contact_with_black_police * time
    
    m.loc['White_Police_At_Work', 'White_Police_At_Work'] = (MAX_OCCUPATION_INFECTION_NUMBER - white_police_contacts_with_whites - white_police_contacts_with_blacks) * white_of_black_white_police #E37-B41-B44 * B28
    m.loc['White_Police_At_Work', 'Black_Police_At_Work'] = (MAX_OCCUPATION_INFECTION_NUMBER - white_police_contacts_with_whites - white_police_contacts_with_blacks) * black_of_black_white_police
    
    m.loc['Black_Police_At_Work', 'White_Police_At_Work'] = (MAX_OCCUPATION_INFECTION_NUMBER - black_police_contacts_with_whites - black_police_contacts_with_blacks) * white_of_black_white_police
    m.loc['Black_Police_At_Work', 'Black_Police_At_Work'] = (MAX_OCCUPATION_INFECTION_NUMBER - black_police_contacts_with_whites - black_police_contacts_with_blacks) * black_of_black_white_police
    return m


contact_matrix = fill_in_police_job_contacts(contact_matrix)

#Target for totals is the proportion of hours at work or at home * the expected number of contacts per day (?week?)
# Out:
# Black_Forced_Labour_At_Home
# Black_Non_Essential_Labour_At_Home
# Black_Non_Working
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
contact_matrix[['White_Police_At_Work', 'Black_Police_At_Work']]
# Out:
#                                     White_Police_At_Work  Black_Police_At_Work
# i
# White_Forced_Labour_At_Work                     0.000000              0.000000
# White_Forced_Labour_At_Home                     0.005471              0.000708
# White_Non_Essential_Labour_At_Work              0.000000              0.000000
# White_Non_Essential_Labour_At_Home              0.005471              0.000708
# White_Police_At_Work                            7.284079              2.623245
# White_Police_At_Home                            0.000000              0.000000
# White_Non_Working                               0.008510              0.001102
# White_Prison                                    0.000000              0.000000
# Black_Forced_Labour_At_Work                     0.000000              0.000000
# Black_Forced_Labour_At_Home                     0.009837              0.001274
# Black_Non_Essential_Labour_At_Work              0.000000              0.000000
# Black_Non_Essential_Labour_At_Home              0.009837              0.001274
# Black_Police_At_Work                           10.620782              3.824905
# Black_Police_At_Home                            0.000000              0.000000
# Black_Non_Working                               0.015302              0.001981
# Black_Prison                                    0.000000              0.000000

# %%
def fill_in_prison_contacts(m):
    #All hard coded from EXPANDED_CONTACT_MATRIX_PRE_SIP B78, at some point we should put the calculations to get here in the spreadsheet
    WHITE_RELEASE_RATE = 0.00007130892426
    BLACK_RELEASE_RATE = 0.0002163545656
    white_weekly_release_rate = WHITE_RELEASE_RATE * 7
    black_weekly_release_rate = BLACK_RELEASE_RATE * 7
    white_release_rate_delay = white_weekly_release_rate * DAYS_UNTIL_RECOVERY * 0.5 # don't understand the 0.5
    black_release_rate_delay = black_weekly_release_rate * DAYS_UNTIL_RECOVERY * 0.5 
    
    white_prison = white_release_rate_delay * NO_SOCIAL_DISTANCING_INFECTION_RATE
    black_prison = black_release_rate_delay * NO_SOCIAL_DISTANCING_INFECTION_RATE
    
    for i in group_df.index.values:
        if group_df.loc[i, 'Location'] == 'Home':
            
            if group_df.loc[i, 'Race'] == 'Black':
                m.loc[i, 'Black_Prison'] = black_prison * group_df.iloc[i, 'Home_Hours']
            else:
                m.loc[i, 'Black_Prison'] = black_prison * group_df.iloc[i, 'Home_Hours']
    
    #black_police_work --> black_prison
    #See Row L .. i don't understand this logic. 
    m.loc['White_Police_At_Work', 'White_Prison'] = white_prison * white_police_contacts_with_whites
    m.loc['White_Police_At_Work', 'Black_Prison'] = black_prison * white_police_contacts_with_blacks
    
    m.loc['Black_Police_At_Work', 'Black_Prison'] = black_prison * black_police_contacts_with_blacks
    m.loc['Black_Police_At_Work', 'White_Prison'] = white_prison * black_police_contacts_with_whites
    return m

contact_matrix = fill_in_prison_contacts(contact_matrix)

# %%
def fill_in_home_contacts(m):
    for a in group_df.index.values:
        if group_df.loc[a, 'Location'] == 'At_Home':
            # Its not what we did in the spread sheet but maybe we should be subtracting these from target contacts 
#             other_contacts = m.loc[a][['Black_Police_At_Work', 'Black_Prison', 'White_Police_At_Work', 'White_Prison']].sum()
#             remaining_contacts = group_df.loc[a, 'Target_Contacts'] - other_contacts
            if group_df.loc[a, 'Race'] == 'Black':
                
                for b in black_neighborhood.index.values:
                    m.loc[a, b] = black_neighborhood.loc[b, 'hours_prop'] * group_df.loc[a, 'Target_Contacts']
            else:
                for w in white_neighborhood.index.values:
                    total_hours = black_neighborhood['Race_Home_Hours'].sum()
                    m.loc[a, w] = white_neighborhood.loc[w, 'hours_prop'] * group_df.loc[a, 'Target_Contacts'] 
    return m

contact_matrix = fill_in_home_contacts(contact_matrix)

# %%
contact_matrix
# Out:
#                                     White_Forced_Labour_At_Work  \
# i
# White_Forced_Labour_At_Work                            2.471917
# White_Forced_Labour_At_Home                            0.000000
# White_Non_Essential_Labour_At_Work                     0.882827
# White_Non_Essential_Labour_At_Home                     0.000000
# White_Police_At_Work                                   0.000000
# White_Police_At_Home                                   0.000000
# White_Non_Working                                      0.000000
# White_Prison                                           0.000000
# Black_Forced_Labour_At_Work                            2.471917
# Black_Forced_Labour_At_Home                            0.000000
# Black_Non_Essential_Labour_At_Work                     0.882827
# Black_Non_Essential_Labour_At_Home                     0.000000
# Black_Police_At_Work                                   0.000000
# Black_Police_At_Home                                   0.000000
# Black_Non_Working                                      0.000000
# Black_Prison                                           0.000000
#
#                                     White_Forced_Labour_At_Home  \
# i
# White_Forced_Labour_At_Work                            0.000000
# White_Forced_Labour_At_Home                            0.726362
# White_Non_Essential_Labour_At_Work                     0.000000
# White_Non_Essential_Labour_At_Home                     0.726362
# White_Police_At_Work                                   0.445561
# White_Police_At_Home                                   0.726362
# White_Non_Working                                      1.129897
# White_Prison                                           0.000000
# Black_Forced_Labour_At_Work                            0.000000
# Black_Forced_Labour_At_Home                            0.000000
# Black_Non_Essential_Labour_At_Work                     0.000000
# Black_Non_Essential_Labour_At_Home                     0.000000
# Black_Police_At_Work                                   0.160462
# Black_Police_At_Home                                   0.000000
# Black_Non_Working                                      0.000000
# Black_Prison                                           0.000000
#
#                                     White_Non_Essential_Labour_At_Work  \
# i
# White_Forced_Labour_At_Work                                   8.237525
# White_Forced_Labour_At_Home                                   0.000000
# White_Non_Essential_Labour_At_Work                            2.941973
# White_Non_Essential_Labour_At_Home                            0.000000
# White_Police_At_Work                                          0.000000
# White_Police_At_Home                                          0.000000
# White_Non_Working                                             0.000000
# White_Prison                                                  0.000000
# Black_Forced_Labour_At_Work                                   8.237525
# Black_Forced_Labour_At_Home                                   0.000000
# Black_Non_Essential_Labour_At_Work                            2.941973
# Black_Non_Essential_Labour_At_Home                            0.000000
# Black_Police_At_Work                                          0.000000
# Black_Police_At_Home                                          0.000000
# Black_Non_Working                                             0.000000
# Black_Prison                                                  0.000000
#
#                                     White_Non_Essential_Labour_At_Home  \
# i
# White_Forced_Labour_At_Work                                   0.000000
# White_Forced_Labour_At_Home                                   2.420562
# White_Non_Essential_Labour_At_Work                            0.000000
# White_Non_Essential_Labour_At_Home                            2.420562
# White_Police_At_Work                                          1.484806
# White_Police_At_Home                                          2.420562
# White_Non_Working                                             3.765318
# White_Prison                                                  0.000000
# Black_Forced_Labour_At_Work                                   0.000000
# Black_Forced_Labour_At_Home                                   0.000000
# Black_Non_Essential_Labour_At_Work                            0.000000
# Black_Non_Essential_Labour_At_Home                            0.000000
# Black_Police_At_Work                                          0.534729
# Black_Police_At_Home                                          0.000000
# Black_Non_Working                                             0.000000
# Black_Prison                                                  0.000000
#
#                                     White_Police_At_Work  \
# i
# White_Forced_Labour_At_Work                     0.000000
# White_Forced_Labour_At_Home                     0.005471
# White_Non_Essential_Labour_At_Work              0.000000
# White_Non_Essential_Labour_At_Home              0.005471
# White_Police_At_Work                            7.284079
# White_Police_At_Home                            0.000000
# White_Non_Working                               0.008510
# White_Prison                                    0.000000
# Black_Forced_Labour_At_Work                     0.000000
# Black_Forced_Labour_At_Home                     0.009837
# Black_Non_Essential_Labour_At_Work              0.000000
# Black_Non_Essential_Labour_At_Home              0.009837
# Black_Police_At_Work                           10.620782
# Black_Police_At_Home                            0.000000
# Black_Non_Working                               0.015302
# Black_Prison                                    0.000000
#
#                                     White_Police_At_Home  White_Non_Working  \
# i
# White_Forced_Labour_At_Work                     0.000000           0.000000
# White_Forced_Labour_At_Home                     0.010837           5.107545
# White_Non_Essential_Labour_At_Work              0.000000           0.000000
# White_Non_Essential_Labour_At_Home              0.010837           5.107545
# White_Police_At_Work                            0.000000           3.133039
# White_Police_At_Home                            0.010837           5.107545
# White_Non_Working                               0.016858           7.945071
# White_Prison                                    0.000000           0.000000
# Black_Forced_Labour_At_Work                     0.000000           0.000000
# Black_Forced_Labour_At_Home                     0.000000           0.000000
# Black_Non_Essential_Labour_At_Work              0.000000           0.000000
# Black_Non_Essential_Labour_At_Home              0.000000           0.000000
# Black_Police_At_Work                            0.000000           1.128314
# Black_Police_At_Home                            0.000000           0.000000
# Black_Non_Working                               0.000000           0.000000
# Black_Prison                                    0.000000           0.000000
#
#                                     White_Prison  Black_Forced_Labour_At_Work  \
# i
# White_Forced_Labour_At_Work             0.000000                     0.663936
# White_Forced_Labour_At_Home             0.000000                     0.000000
# White_Non_Essential_Labour_At_Work      0.000000                     0.237120
# White_Non_Essential_Labour_At_Home      0.000000                     0.000000
# White_Police_At_Work                    0.071748                     0.000000
# White_Police_At_Home                    0.000000                     0.000000
# White_Non_Working                       0.000000                     0.000000
# White_Prison                            0.000000                     0.000000
# Black_Forced_Labour_At_Work             0.000000                     0.663936
# Black_Forced_Labour_At_Home             0.000000                     0.000000
# Black_Non_Essential_Labour_At_Work      0.000000                     0.237120
# Black_Non_Essential_Labour_At_Home      0.000000                     0.000000
# Black_Police_At_Work                    0.025839                     0.000000
# Black_Police_At_Home                    0.000000                     0.000000
# Black_Non_Working                       0.000000                     0.000000
# Black_Prison                            0.000000                     0.000000
#
#                                     Black_Forced_Labour_At_Home  \
# i
# White_Forced_Labour_At_Work                            0.000000
# White_Forced_Labour_At_Home                            0.000000
# White_Non_Essential_Labour_At_Work                     0.000000
# White_Non_Essential_Labour_At_Home                     0.000000
# White_Police_At_Work                                   0.213863
# White_Police_At_Home                                   0.000000
# White_Non_Working                                      0.000000
# White_Prison                                           0.000000
# Black_Forced_Labour_At_Work                            0.000000
# Black_Forced_Labour_At_Home                            0.873937
# Black_Non_Essential_Labour_At_Work                     0.000000
# Black_Non_Essential_Labour_At_Home                     0.873937
# Black_Police_At_Work                                   0.077019
# Black_Police_At_Home                                   0.873937
# Black_Non_Working                                      1.359458
# Black_Prison                                           0.000000
#
#                                     Black_Non_Essential_Labour_At_Work  \
# i
# White_Forced_Labour_At_Work                                   1.483765
# White_Forced_Labour_At_Home                                   0.000000
# White_Non_Essential_Labour_At_Work                            0.529916
# White_Non_Essential_Labour_At_Home                            0.000000
# White_Police_At_Work                                          0.000000
# White_Police_At_Home                                          0.000000
# White_Non_Working                                             0.000000
# White_Prison                                                  0.000000
# Black_Forced_Labour_At_Work                                   1.483765
# Black_Forced_Labour_At_Home                                   0.000000
# Black_Non_Essential_Labour_At_Work                            0.529916
# Black_Non_Essential_Labour_At_Home                            0.000000
# Black_Police_At_Work                                          0.000000
# Black_Police_At_Home                                          0.000000
# Black_Non_Working                                             0.000000
# Black_Prison                                                  0.000000
#
#                                     Black_Non_Essential_Labour_At_Home  \
# i
# White_Forced_Labour_At_Work                                   0.000000
# White_Forced_Labour_At_Home                                   0.000000
# White_Non_Essential_Labour_At_Work                            0.000000
# White_Non_Essential_Labour_At_Home                            0.000000
# White_Police_At_Work                                          0.477942
# White_Police_At_Home                                          0.000000
# White_Non_Working                                             0.000000
# White_Prison                                                  0.000000
# Black_Forced_Labour_At_Work                                   0.000000
# Black_Forced_Labour_At_Home                                   1.953077
# Black_Non_Essential_Labour_At_Work                            0.000000
# Black_Non_Essential_Labour_At_Home                            1.953077
# Black_Police_At_Work                                          0.172123
# Black_Police_At_Home                                          1.953077
# Black_Non_Working                                             3.038119
# Black_Prison                                                  0.000000
#
#                                     Black_Police_At_Work  \
# i
# White_Forced_Labour_At_Work                     0.000000
# White_Forced_Labour_At_Home                     0.000708
# White_Non_Essential_Labour_At_Work              0.000000
# White_Non_Essential_Labour_At_Home              0.000708
# White_Police_At_Work                            2.623245
# White_Police_At_Home                            0.000000
# White_Non_Working                               0.001102
# White_Prison                                    0.000000
# Black_Forced_Labour_At_Work                     0.000000
# Black_Forced_Labour_At_Home                     0.001274
# Black_Non_Essential_Labour_At_Work              0.000000
# Black_Non_Essential_Labour_At_Home              0.001274
# Black_Police_At_Work                            3.824905
# Black_Police_At_Home                            0.000000
# Black_Non_Working                               0.001981
# Black_Prison                                    0.000000
#
#                                     Black_Police_At_Home  Black_Non_Working  \
# i
# White_Forced_Labour_At_Work                     0.000000           0.000000
# White_Forced_Labour_At_Home                     0.000000           0.000000
# White_Non_Essential_Labour_At_Work              0.000000           0.000000
# White_Non_Essential_Labour_At_Home              0.000000           0.000000
# White_Police_At_Work                            0.000000           1.326546
# White_Police_At_Home                            0.000000           0.000000
# White_Non_Working                               0.000000           0.000000
# White_Prison                                    0.000000           0.000000
# Black_Forced_Labour_At_Work                     0.000000           0.000000
# Black_Forced_Labour_At_Home                     0.017453           5.420839
# Black_Non_Essential_Labour_At_Work              0.000000           0.000000
# Black_Non_Essential_Labour_At_Home              0.017453           5.420839
# Black_Police_At_Work                            0.000000           0.477734
# Black_Police_At_Home                            0.017453           5.420839
# Black_Non_Working                               0.027149           8.432416
# Black_Prison                                    0.000000           0.000000
#
#                                     Black_Prison
# i
# White_Forced_Labour_At_Work             0.000000
# White_Forced_Labour_At_Home             0.000000
# White_Non_Essential_Labour_At_Work      0.000000
# White_Non_Essential_Labour_At_Home      0.000000
# White_Police_At_Work                    0.086842
# White_Police_At_Home                    0.000000
# White_Non_Working                       0.000000
# White_Prison                            0.000000
# Black_Forced_Labour_At_Work             0.000000
# Black_Forced_Labour_At_Home             0.000000
# Black_Non_Essential_Labour_At_Work      0.000000
# Black_Non_Essential_Labour_At_Home      0.000000
# Black_Police_At_Work                    0.031275
# Black_Police_At_Home                    0.000000
# Black_Non_Working                       0.000000
# Black_Prison                            0.000000
